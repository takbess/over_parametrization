# %% [markdown]
# model sizeを上げていくと順当に test_lossが上がって、過学習することが増えているように見える。

# %%
# all_loss.txt を可視化
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("all_loss_v1.txt")
model_size = df.iloc[:,0]
test_loss = df.iloc[:,1]

plt.scatter(model_size,test_loss)

# plt.ylim([0, 1])
plt.show()

# %%
# all_loss.txt を可視化
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("all_loss_v2.txt")
model_size = df.iloc[:,0]
test_loss = df.iloc[:,1]

plt.scatter(model_size,test_loss)

# plt.ylim([0, 1])
plt.show()

# %% [markdown]
# model_size=10, 400,000 epoch学習後の画像は以下のようになる。教科書的な過学習を見られる。
# ![画像例](images/tmp_change_epochs.png)

# %% [markdown]
# model_size=1000の時は学習に時間かかる。
# 2,000 epoch学習後の画像は以下のようになる。
# まだまだ全然fitしていない。
# ![画像例](images/tmp_change_model.n=1000_epochs_2000.png)
# でも、lrを増やすとすぐに吹っ飛んでlossがNaNになる。
#
# 20,000 epoch学習後の画像は以下のようになる。
# まだまだfitしていない部分があるが、だいぶ過学習していると感じられる。
# ![画像例](images/tmp_change_model.n=1000_epochs_20000.png)
#
# Gradient Descent法って、滑らかな部分から先にfitして、滑らかじゃない部分はfitに時間かかるように思えた。
#
# Github上で30分くらいかかった。
#
# 62,800 epoch 回したけど、20,000の時と大差ない。

# %% [markdown]
# 分からない、、、。
# over parametrization論文を読むのが一番良い気がする。
# で、公式、非公式のgithubコードとかあれば上々。
